# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### < 데이터셋 개요>
# - Survived: 생존 여부
#     - 0 = No
#     - 1 = Yes
# - pclass: 티켓 등급
#     - 1 = 1st
#     - 2 = 2nd
#     - 3 = 3rd
# - Sex: 성별
# - Age: 나이
# - Sibsp: 함께 탑승한 형제자매, 배우자의 수
# - Parch: 함께 탑승한 부모, 자식의 수
# - Ticket: 티켓 번호
# - Name : 이름, 사회적등급
# - Fare: 운임
# - Cabin: 객실 번호
# - Embarked: 탑승 항구
#     - C = Cherbourg
#     - Q = Queenstown
#     - S = Southampton

# %% [markdown]
# #### 데이터 적재

# %%
data = pd.read_csv('data1/train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# columns 소문자로 변형
# 1) data.rename(columns = str, lower)
# 2) data.columns = data.columns.map(lower)
data.columns = data.columns.str.lower()
data.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 결측치 확인
#
# - columns 갯수
# - data set의 크기가 작은 경우는 결측치가 있는 레코드를 삭제하지 않음
#     - 대체하는 방식으로 전처리

# %%
data.shape
# Out:
# (891, 12)

# %%
# data.isnull()은 값이 있으면 False, 없으면 True를 셀에 배치
# python 특성상 True는 1로 간주 False는 0으로 간주
# isnull
data.isnull().sum()
# Out:
# passengerid      0
# survived         0
# pclass           0
# name             0
# sex              0
# age            177
# sibsp            0
# parch            0
# ticket           0
# fare             0
# cabin          687
# embarked         2
# dtype: int64

# %%
# 전체 데이터 대비 결측치의 비중
# 결측치 / 891(전체데이터개수) * 100 = 비율
data.isnull().sum() / 891 * 100
# Out:
# passengerid     0.000000
# survived        0.000000
# pclass          0.000000
# name            0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# ticket          0.000000
# fare            0.000000
# cabin          77.104377
# embarked        0.224467
# dtype: float64

# %% [markdown]
# #### 불필요한 볌수 제거
#
# - ticket

# %%
data
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      parch            ticket     fare cabin embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# ticket columns 누락시키기
# del data['ticket']
data.drop('ticket', axis=1, inplace = True)
data.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch     fare cabin embarked
# 0      0   7.2500   NaN        S
# 1      0  71.2833   C85        C
# 2      0   7.9250   NaN        S
# 3      0  53.1000  C123        S
# 4      0   8.0500   NaN        S

# %%
# 누락확인
'ticket' in data.columns
# Out:
# False

# %%
# ticket columns 을 누락시킨 csv file 을 외부톨 빼내기
# ticket_deleted_titanic.csv 이름으로 저장
# df.to_csv('name.csv')
# Unnamed : 0 columns를 방지하기 위해 index=False를 넣기
data.to_csv('ticket_deleted_titanic.csv', index = False)

# %% [markdown]
# #### Cabin 데이터를 활용하여 유도변수 생성
# - 개별 객실 번호는 의미가 없음(123, 456 ...)
# - cabin 데이터의 첫 글자가 deck(구역)을 의미
# - 유도변수 : deck컬럼 추가
# - deck 컬럼에 추가될 자료 : A, B, C, D, E, F, G, T, unknown

# %% [markdown]
# - cabin 컬럼의 각 값에 적용할 처리
#     - 1)
#         - 값의 첫 번째 문자가 deck list에 있으면 해당 deck을 반환
#         - 없으면(NaN) deck list의 unknown 반환
#     - 2)
#         - 첫 번째 문자 반환
#         - 없으면 다른 것 반환

# %%
# NaN
# 1. type = float
# 2. 다른 값으로 대체해서 처리
# 3. str으로 변경

# %%
deck_list = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'T', 'unknown']
sample = ['C123', np.nan, 'D201', np.nan,'F999']
# result = ['C', 'unknown', 'D', 'unknown', 'F']

# %%
type(np.NaN)
# Out:
# float

# %%
# 함수를 정의하여 apply와 map을 통해 유도변수로 교체
def cabin_to_deck(value):
    deck_list = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'T', 'unknown']

    # NaN인지 검사
    if type(value) == type(np.nan):
        return 'unknown'
    # 덱 리스트에 분류된 덱이 맞는지 체크
    elif value[0] in deck_list:
        return value[0]
    # NaN가 아니면 덱 종류만 return
    else:
        return 'unknown'

# %%
# column_name 'deck'
data['deck'] = data['cabin'].map(cabin_to_deck)

# %%
data['deck']
# Out:
# 0      unknown
# 1            C
# 2      unknown
# 3            C
# 4      unknown
#         ...
# 886    unknown
# 887          B
# 888    unknown
# 889          C
# 890    unknown
# Name: deck, Length: 891, dtype: object

# %% [markdown]
# #### Name 데이터를 활용하여 유도변수 생성
#
#
# - 개별 이름은 모델 예측에 유의미한 변수가 아니다.
# - 대표 특성을 찾을 수 있는 범주 데이터를 추출할 수 있다.
# - Mr, Ms, Miss, Master ...
# - 추출 하여 title 컬럼으로 추가
# - 첫번째 방법. split() 두번 사용하여 처리
# - 두번째 방법. 정규식을 사용하여 처리
#     - ver1
#         - 정규식 패턴 생성에 사용할 문자열 : Sir, Mr, Don, Major, Capt, Jonkheer, Rev, Col, Dr, Mrs, Countess, Dona, Mme, Ms, Miss, Mlle, Master
#         - 정규식 사용 순서 : 원본 문자열에서 split 결과의 1번 인덱스 값
#     - ver2
#         - 정규식 패턴 : [a-zA-Z]+\.

# %%
# split 을 활용해서, name columns 값들을 칭호만 남겨서 저장
# 새로운 column splited_name column에 저장
def name_split(value):
    return value.split(', ')[1].split('.')[0]

# %%
data['splited_name'] = data['name'].apply(name_split)

# %%
data['splited_name'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
# 정규표현식 사용을 위해 import re 실행
# regular expression(정규 표현식)
import re

# %%
# 정규표현식은 re.compile('내부 패턴', re.I)를 이용하면 해당 단어만 뽑아줍니다.
# 이를 위해서 반드시 먼저 import re 가 실행되어 있어야 합니다.
# 단어 리스트를 가지고 정규식 패턴 적용
def get_title(name):
    # 둘 이상의 단어를 타겟으로 잡을때는 |(쉬프트 + 역슬래시)를 사용합니다.
    pattern = re.compile('Sir|Mrs|Don|Major|Capt|Jonkheer|Rev|Col|Dr|Mr|\
        Countess|Dona|Mme|Ms|Miss|Mlle|Master', re.I)
    # 정규식변수.search(타겟) => 타겟에서 패턴에 해당하는 자료가 있는지 조사
    result = pattern.search(name)
    if result:
        return result.group().lower()
    else:
        str(np.nan)

# %%
get_title('the Capt,man')
# Out:
# 'capt'

# %%
data['name'].apply(get_title)
data
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      parch     fare cabin embarked     deck splited_name
# 0        0   7.2500   NaN        S  unknown           Mr
# 1        0  71.2833   C85        C        C          Mrs
# 2        0   7.9250   NaN        S  unknown         Miss
# 3        0  53.1000  C123        S        C          Mrs
# 4        0   8.0500   NaN        S  unknown           Mr
# ..     ...      ...   ...      ...      ...          ...
# 886      0  13.0000   NaN        S  unknown          Rev
# 887      0  30.0000   B42        S        B         Miss
# 888      2  23.4500   NaN        S  unknown         Miss
# 889      0  30.0000  C148        C        C           Mr
# 890      0   7.7500   NaN        Q  unknown           Mr
#
# [891 rows x 13 columns]

# %%
# 위 정규식 실행 함수를 name에 적용하면 호칭만 뽑혀나옴
data['title'] = data['name'].apply(get_title)
data
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      parch     fare cabin embarked     deck splited_name title
# 0        0   7.2500   NaN        S  unknown           Mr    mr
# 1        0  71.2833   C85        C        C          Mrs   mrs
# 2        0   7.9250   NaN        S  unknown         Miss  miss
# 3        0  53.1000  C123        S        C          Mrs   mrs
# 4        0   8.0500   NaN        S  unknown           Mr    mr
# ..     ...      ...   ...      ...      ...          ...   ...
# 886      0  13.0000   NaN        S  unknown          Rev   rev
# 887      0  30.0000   B42        S        B         Miss  miss
# 888      2  23.4500   NaN        S  unknown         Miss  miss
# 889      0  30.0000  C148        C        C           Mr    mr
# 890      0   7.7500   NaN        Q  unknown           Mr    mr
#
# [891 rows x 14 columns]

# %%
# re를 사용하지 않는 경우는 팬더스에서 .str.extract('패턴')를 사용함
# expand=False를 주지 않으면 DataFrame형으로 나옴
data['name'].str.extract('([a-zA-Z]+)\.', expand=False)
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: name, Length: 891, dtype: object

# %%
# 호칭별 개수
data['title'].value_counts()
# Out:
# Mr         493
# Miss       179
# Mrs        135
# Officer     39
# Royalty      5
# Name: title, dtype: int64

# %% [markdown]
# #### Name 데이터를 활용하여 생성한 유도변수 처리

# %% [markdown]
# * 범주 재설정
#
#     capt - Officer
#
#     col - Officer
#
#     major - Officer
#
#     dr - Officer
#
#     jonkheer - Royalty
#
#     rev - Officer
#
#     countess - Royalty
#
#     dona - Royalty
#
#     lady - Royalty
#
#     don - Royalty
#
#     sir - Officer
#
#     mr - Mr
#
#     mme - Mrs
#
#     ms - Mrs
#
#     mrs - Mrs
#
#     miss - Miss
#
#     mlle - Miss
#
#     master - Master
#
#     nan - Mr(최빈값)

# %%
title_map = {
    "capt":"Officer",
    "col":"Officer",
    "major":"Officer",
    "dr":"Officer",
    "jonkheer":"Royalty",
    "rev":"Officer",
    "countess":"Royalty",
    "dona":"Royalty",
    "lady":"Royalty",
    "don":"Royalty",
    'sir' : 'Officer',
    "mr":"Mr",
    "mme":"Mrs",
    "ms":"Mrs",
    "mrs":"Mrs",
    "miss":"Miss",
    "mlle":"Miss",
}

# %%
# data['title']에 들어있던 요소를 위의 규칙을 따라서 내부요소 변경하기
data['title'] = data['title'].map(title_map)
data['title']
# Out:
# 0           Mr
# 1          Mrs
# 2         Miss
# 3          Mrs
# 4           Mr
#         ...
# 886    Officer
# 887       Miss
# 888       Miss
# 889         Mr
# 890         Mr
# Name: title, Length: 891, dtype: object

# %% [markdown]
# #### 결측치 처리 - Age
#
# - 미성년(Master, Miss)
# - title 별 평균으로 age 결측치 대체
# - transform
# - (참고)사용자정의함수 : 매개변수 3개(타이틀별평균, 데이터, 타이틀리스트)

# %%
# data columns 중 null이 들어온 columns 개수를 구하시오
data.age.isnull().sum()
# Out:
# 177

# %%
# df['col'].transform(mean)
# df['col'].mean()
# df['col'].apply(lambda x : mean(x))
# df['col'].apply(함수)

# %%
# title별 age의 평균값
# groupby를 이용해 'title' columns age mean을 구하시오
data.groupby('title')[['age']].mean()
# Out:
#                age
# title
# Miss     21.555556
# Mr       32.346457
# Mrs      35.659292
# Officer  37.742857
# Royalty  48.200000

# %%
data['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
# groupby 다음 사용하는 transform은 기존 값을 무시하고, 집계함수값으로 대체
#data.groupby('title')['age'].transform('mean')
# title column을 기준으로 묶은 자료들의 'age' columns 평균치로
# 원래 'age'에 있던 결측치를 대신하기 위해 fillna를 사용
data['age'].fillna(data.groupby('title')['age'].transform('mean'),inplace=True)
data['age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    21.555556
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
# 결측치가 사라졌는데 isnull().sum()으로 확인
data['age'].isnull().sum()
# Out:
# 4

# %% [markdown]
# #### Age 데이터를 범주형 데이터로 변경
#
# - 나이 숫자값 자체로는 의미가 적음
# - 연령대로 구분하는 것이 더 의미가 있는 구분값
# - 구간
#     - ~20
#     - 20~40
#     - 40~60
#     - 60~
# - 개수 : 4개
# - pd.cut / np.digitize

# %%
# 사용자 정의함수
def age_class(value):
    if value < 20:
        return 'under20'
    elif value < 40:
        return '20~40'
    elif value < 60:
        return '40~60'
    else:
        return 'over60'

# %%
# data['age_class']를 만들어 저장
# 내부의 값 하나하나를 함수 age_class 를 이용해 나이대별로 분류

# %%
data['age_class'] = data['age'].map(age_class)
data['age_class']
# Out:
# 0        20~40
# 1        20~40
# 2        20~40
# 3        20~40
# 4        20~40
#         ...
# 886      20~40
# 887    under20
# 888      20~40
# 889      20~40
# 890      20~40
# Name: age_class, Length: 891, dtype: object

# %%
# 연령대별 생존 비율
# stacked bar chart
# 연령대별로 데이터가 몇 개 있는지
data['age_class'].value_counts()
# Out:
# 20~40      560
# under20    164
# 40~60      137
# over60      30
# Name: age_class, dtype: int64

# %%
# groupby를 이용해, 연령대별 생존/사망 명수를 출력
age_classed_data = data.groupby(['age_class','survived','sex'])[['survived']].count().copy()

# %%
age_classed_data
# Out:
#                            survived
# age_class survived sex
# 20~40     0        female        47
#                    male         313
#           1        female       138
#                    male          62
# 40~60     0        female        12
#                    male          71
#           1        female        38
#                    male          16
# over60    0        male          21
#           1        female         4
#                    male           5
# under20   0        female        22
#                    male          63
#           1        female        53
#                    male          26

# %%
# barplot, stacked 형태로 그리기
# DataFrame 에 바로 plot(), hist() 등을 사용하면 실제로 그려줌
# survived를 x축에(row), 나이정보를 y축에(column)으로 두기 위해 unstack() 실행
barplot_data = age_classed_data.unstack(0).plot(kind='bar', stacked=True)
plt.show()

# %%
barplot_data.plot(kind='bar',stacked=True)
# Out:
# []

# %% [markdown]
# #### 성별별 생존자, 탑승표 등급별 생존자 분석

# %%
# 탑승표 등급별 생존자를 시각화
# 1. 생존자와 사망자를 탑승표로 분류해서 가공
# 2. 차트로 만들기

# %%
# x축엔 생존여부(row 내지는 index에 survived가 와야함)
# y축에는 탑승표 종류(columns 에 pclass가 와아함)
pclassed_data = data.groupby(['pclass','survived'])[['survived']].count()

# %%
pclassed_data.unstack(0).plot(kind='bar', stacked=True)
plt.show()
